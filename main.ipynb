# %% [markdown]
# # Transmissão COVID
#
# Este projeto tem como foco identificar uma pessoa que está contaminada com COVID e outra pessoa que não está, verificando qual o caminho mais propício para a transmissão do vírus

# %% [markdown]
# Vamos importar as bibliotecas que vão nos ajudar a visualizar o grafo e também nos oferecer um conjunto de grafos já construído

# %%
import networkx as nx
import matplotlib.pyplot as plt
import ipywidgets as widgets

# %% [markdown]
# Aqui importamos os dados das relações dos personagens de os Miseráveis, cujo grafo vamos utilizar para simular as relações entre as pessoas

# %%
g = nx.generators.social.les_miserables_graph()

# %% [markdown]
# Aqui vamos plotar o grafo para identificar as relações de uma forma mais abstrata

# %%
G = g
pos = nx.spring_layout(G, seed=7)

plt.figure(figsize=(12,12))

# nodes
nx.draw_networkx_nodes(G, pos, node_size=400)

nx.draw_networkx_edges(G,pos)

weights = [d['weight']/10 for (u, v, d) in G.edges(data=True)]
colors = [d['weight'] for (u, v, d) in G.edges(data=True)]

nx.draw_networkx_edges(G, pos, width=weights, edge_color=colors, alpha=1)

# labels
nx.draw_networkx_labels(G, pos, font_size=10, font_family="sans-serif")

plt.show()

# %% [markdown]
# O objeto grafo que temos está em uma classe Graph, do próprio NetworkX, porém para manipulá-lo e utilizar um estrutura de dados que não simplifique muito, vamos converte para um dicionário em Python, que vai servir para simular uma lista de adjacência.

# %%
G_dict = nx.convert.to_dict_of_dicts(g)

# %% [markdown]
# Aqui vamos ver qual o formato da estrutura de dados e como os dados estão distribuídos no grafo.

# %%
for k,v in G_dict.items():
    print(k,v)
# Out:
# Napoleon {'Myriel': {'weight': 1}}
# Myriel {'Napoleon': {'weight': 1}, 'MlleBaptistine': {'weight': 8}, 'MmeMagloire': {'weight': 10}, 'CountessDeLo': {'weight': 1}, 'Geborand': {'weight': 1}, 'Champtercier': {'weight': 1}, 'Cravatte': {'weight': 1}, 'Count': {'weight': 2}, 'OldMan': {'weight': 1}, 'Valjean': {'weight': 5}}
# MlleBaptistine {'Myriel': {'weight': 8}, 'MmeMagloire': {'weight': 6}, 'Valjean': {'weight': 3}}
# MmeMagloire {'Myriel': {'weight': 10}, 'MlleBaptistine': {'weight': 6}, 'Valjean': {'weight': 3}}
# CountessDeLo {'Myriel': {'weight': 1}}
# Geborand {'Myriel': {'weight': 1}}
# Champtercier {'Myriel': {'weight': 1}}
# Cravatte {'Myriel': {'weight': 1}}
# Count {'Myriel': {'weight': 2}}
# OldMan {'Myriel': {'weight': 1}}
# Valjean {'Labarre': {'weight': 1}, 'MmeMagloire': {'weight': 3}, 'MlleBaptistine': {'weight': 3}, 'Myriel': {'weight': 5}, 'Marguerite': {'weight': 1}, 'MmeDeR': {'weight': 1}, 'Isabeau': {'weight': 1}, 'Gervais': {'weight': 1}, 'Fantine': {'weight': 9}, 'MmeThenardier': {'weight': 7}, 'Thenardier': {'weight': 12}, 'Cosette': {'weight': 31}, 'Javert': {'weight': 17}, 'Fauchelevent': {'weight': 8}, 'Bamatabois': {'weight': 2}, 'Simplice': {'weight': 3}, 'Scaufflaire': {'weight': 1}, 'Woman1': {'weight': 2}, 'Judge': {'weight': 3}, 'Champmathieu': {'weight': 3}, 'Brevet': {'weight': 2}, 'Chenildieu': {'weight': 2}, 'Cochepaille': {'weight': 2}, 'Woman2': {'weight': 3}, 'MotherInnocent': {'weight': 1}, 'Gavroche': {'weight': 1}, 'Gillenormand': {'weight': 2}, 'MlleGillenormand': {'weight': 2}, 'Marius': {'weight': 19}, 'Enjolras': {'weight': 4}, 'Bossuet': {'weight': 1}, 'Gueulemer': {'weight': 1}, 'Babet': {'weight': 1}, 'Claquesous': {'weight': 1}, 'Montparnasse': {'weight': 1}, 'Toussaint': {'weight': 1}}
# Labarre {'Valjean': {'weight': 1}}
# Marguerite {'Valjean': {'weight': 1}, 'Fantine': {'weight': 2}}
# MmeDeR {'Valjean': {'weight': 1}}
# Isabeau {'Valjean': {'weight': 1}}
# Gervais {'Valjean': {'weight': 1}}
# Listolier {'Tholomyes': {'weight': 4}, 'Fameuil': {'weight': 4}, 'Blacheville': {'weight': 4}, 'Favourite': {'weight': 3}, 'Dahlia': {'weight': 3}, 'Zephine': {'weight': 3}, 'Fantine': {'weight': 3}}
# Tholomyes {'Listolier': {'weight': 4}, 'Fameuil': {'weight': 4}, 'Blacheville': {'weight': 4}, 'Favourite': {'weight': 3}, 'Dahlia': {'weight': 3}, 'Zephine': {'weight': 3}, 'Fantine': {'weight': 3}, 'Cosette': {'weight': 1}, 'Marius': {'weight': 1}}
# Fameuil {'Tholomyes': {'weight': 4}, 'Listolier': {'weight': 4}, 'Blacheville': {'weight': 4}, 'Favourite': {'weight': 3}, 'Dahlia': {'weight': 3}, 'Zephine': {'weight': 3}, 'Fantine': {'weight': 3}}
# Blacheville {'Tholomyes': {'weight': 4}, 'Listolier': {'weight': 4}, 'Fameuil': {'weight': 4}, 'Favourite': {'weight': 4}, 'Dahlia': {'weight': 3}, 'Zephine': {'weight': 3}, 'Fantine': {'weight': 3}}
# Favourite {'Tholomyes': {'weight': 3}, 'Listolier': {'weight': 3}, 'Fameuil': {'weight': 3}, 'Blacheville': {'weight': 4}, 'Dahlia': {'weight': 5}, 'Zephine': {'weight': 4}, 'Fantine': {'weight': 4}}
# Dahlia {'Tholomyes': {'weight': 3}, 'Listolier': {'weight': 3}, 'Fameuil': {'weight': 3}, 'Blacheville': {'weight': 3}, 'Favourite': {'weight': 5}, 'Zephine': {'weight': 4}, 'Fantine': {'weight': 4}}
# Zephine {'Tholomyes': {'weight': 3}, 'Listolier': {'weight': 3}, 'Fameuil': {'weight': 3}, 'Blacheville': {'weight': 3}, 'Favourite': {'weight': 4}, 'Dahlia': {'weight': 4}, 'Fantine': {'weight': 4}}
# Fantine {'Tholomyes': {'weight': 3}, 'Listolier': {'weight': 3}, 'Fameuil': {'weight': 3}, 'Blacheville': {'weight': 3}, 'Favourite': {'weight': 4}, 'Dahlia': {'weight': 4}, 'Zephine': {'weight': 4}, 'Marguerite': {'weight': 2}, 'Valjean': {'weight': 9}, 'MmeThenardier': {'weight': 2}, 'Thenardier': {'weight': 1}, 'Javert': {'weight': 5}, 'Bamatabois': {'weight': 1}, 'Perpetue': {'weight': 1}, 'Simplice': {'weight': 2}}
# MmeThenardier {'Fantine': {'weight': 2}, 'Valjean': {'weight': 7}, 'Thenardier': {'weight': 13}, 'Cosette': {'weight': 4}, 'Javert': {'weight': 1}, 'Eponine': {'weight': 2}, 'Anzelma': {'weight': 1}, 'Magnon': {'weight': 1}, 'Gueulemer': {'weight': 1}, 'Babet': {'weight': 1}, 'Claquesous': {'weight': 1}}
# Thenardier {'MmeThenardier': {'weight': 13}, 'Fantine': {'weight': 1}, 'Valjean': {'weight': 12}, 'Cosette': {'weight': 1}, 'Javert': {'weight': 5}, 'Pontmercy': {'weight': 1}, 'Boulatruelle': {'weight': 1}, 'Eponine': {'weight': 3}, 'Anzelma': {'weight': 2}, 'Gavroche': {'weight': 1}, 'Marius': {'weight': 2}, 'Gueulemer': {'weight': 5}, 'Babet': {'weight': 6}, 'Claquesous': {'weight': 4}, 'Montparnasse': {'weight': 1}, 'Brujon': {'weight': 3}}
# Cosette {'MmeThenardier': {'weight': 4}, 'Valjean': {'weight': 31}, 'Tholomyes': {'weight': 1}, 'Thenardier': {'weight': 1}, 'Javert': {'weight': 1}, 'Woman2': {'weight': 1}, 'Gillenormand': {'weight': 3}, 'MlleGillenormand': {'weight': 2}, 'LtGillenormand': {'weight': 1}, 'Marius': {'weight': 21}, 'Toussaint': {'weight': 2}}
# Javert {'Valjean': {'weight': 17}, 'Fantine': {'weight': 5}, 'Thenardier': {'weight': 5}, 'MmeThenardier': {'weight': 1}, 'Cosette': {'weight': 1}, 'Fauchelevent': {'weight': 1}, 'Bamatabois': {'weight': 1}, 'Simplice': {'weight': 1}, 'Woman1': {'weight': 1}, 'Woman2': {'weight': 1}, 'Gavroche': {'weight': 1}, 'Enjolras': {'weight': 6}, 'Gueulemer': {'weight': 1}, 'Babet': {'weight': 2}, 'Claquesous': {'weight': 1}, 'Montparnasse': {'weight': 1}, 'Toussaint': {'weight': 1}}
# Fauchelevent {'Valjean': {'weight': 8}, 'Javert': {'weight': 1}, 'MotherInnocent': {'weight': 3}, 'Gribier': {'weight': 2}}
# Bamatabois {'Fantine': {'weight': 1}, 'Javert': {'weight': 1}, 'Valjean': {'weight': 2}, 'Judge': {'weight': 2}, 'Champmathieu': {'weight': 2}, 'Brevet': {'weight': 1}, 'Chenildieu': {'weight': 1}, 'Cochepaille': {'weight': 1}}
# Perpetue {'Fantine': {'weight': 1}, 'Simplice': {'weight': 2}}
# Simplice {'Perpetue': {'weight': 2}, 'Valjean': {'weight': 3}, 'Fantine': {'weight': 2}, 'Javert': {'weight': 1}}
# Scaufflaire {'Valjean': {'weight': 1}}
# Woman1 {'Valjean': {'weight': 2}, 'Javert': {'weight': 1}}
# Judge {'Valjean': {'weight': 3}, 'Bamatabois': {'weight': 2}, 'Champmathieu': {'weight': 3}, 'Brevet': {'weight': 2}, 'Chenildieu': {'weight': 2}, 'Cochepaille': {'weight': 2}}
# Champmathieu {'Valjean': {'weight': 3}, 'Judge': {'weight': 3}, 'Bamatabois': {'weight': 2}, 'Brevet': {'weight': 2}, 'Chenildieu': {'weight': 2}, 'Cochepaille': {'weight': 2}}
# Brevet {'Judge': {'weight': 2}, 'Champmathieu': {'weight': 2}, 'Valjean': {'weight': 2}, 'Bamatabois': {'weight': 1}, 'Chenildieu': {'weight': 2}, 'Cochepaille': {'weight': 2}}
# Chenildieu {'Judge': {'weight': 2}, 'Champmathieu': {'weight': 2}, 'Brevet': {'weight': 2}, 'Valjean': {'weight': 2}, 'Bamatabois': {'weight': 1}, 'Cochepaille': {'weight': 2}}
# Cochepaille {'Judge': {'weight': 2}, 'Champmathieu': {'weight': 2}, 'Brevet': {'weight': 2}, 'Chenildieu': {'weight': 2}, 'Valjean': {'weight': 2}, 'Bamatabois': {'weight': 1}}
# Pontmercy {'Thenardier': {'weight': 1}, 'MmePontmercy': {'weight': 1}, 'Marius': {'weight': 1}}
# Boulatruelle {'Thenardier': {'weight': 1}}
# Eponine {'MmeThenardier': {'weight': 2}, 'Thenardier': {'weight': 3}, 'Anzelma': {'weight': 2}, 'Marius': {'weight': 5}, 'Mabeuf': {'weight': 1}, 'Courfeyrac': {'weight': 1}, 'Gueulemer': {'weight': 1}, 'Babet': {'weight': 1}, 'Claquesous': {'weight': 1}, 'Montparnasse': {'weight': 1}, 'Brujon': {'weight': 1}}
# Anzelma {'Eponine': {'weight': 2}, 'Thenardier': {'weight': 2}, 'MmeThenardier': {'weight': 1}}
# Woman2 {'Valjean': {'weight': 3}, 'Cosette': {'weight': 1}, 'Javert': {'weight': 1}}
# MotherInnocent {'Fauchelevent': {'weight': 3}, 'Valjean': {'weight': 1}}
# Gribier {'Fauchelevent': {'weight': 2}}
# MmeBurgon {'Jondrette': {'weight': 1}, 'Gavroche': {'weight': 2}}
# Jondrette {'MmeBurgon': {'weight': 1}}
# Gavroche {'MmeBurgon': {'weight': 2}, 'Thenardier': {'weight': 1}, 'Javert': {'weight': 1}, 'Valjean': {'weight': 1}, 'Marius': {'weight': 4}, 'Mabeuf': {'weight': 1}, 'Enjolras': {'weight': 7}, 'Combeferre': {'weight': 6}, 'Prouvaire': {'weight': 1}, 'Feuilly': {'weight': 2}, 'Courfeyrac': {'weight': 7}, 'Bahorel': {'weight': 5}, 'Bossuet': {'weight': 5}, 'Joly': {'weight': 3}, 'Grantaire': {'weight': 1}, 'Gueulemer': {'weight': 1}, 'Babet': {'weight': 1}, 'Montparnasse': {'weight': 1}, 'Child1': {'weight': 2}, 'Child2': {'weight': 2}, 'Brujon': {'weight': 1}, 'MmeHucheloup': {'weight': 1}}
# Gillenormand {'Cosette': {'weight': 3}, 'Valjean': {'weight': 2}, 'Magnon': {'weight': 1}, 'MlleGillenormand': {'weight': 9}, 'LtGillenormand': {'weight': 1}, 'Marius': {'weight': 12}, 'BaronessT': {'weight': 1}}
# Magnon {'Gillenormand': {'weight': 1}, 'MmeThenardier': {'weight': 1}}
# MlleGillenormand {'Gillenormand': {'weight': 9}, 'Cosette': {'weight': 2}, 'Valjean': {'weight': 2}, 'MmePontmercy': {'weight': 1}, 'MlleVaubois': {'weight': 1}, 'LtGillenormand': {'weight': 2}, 'Marius': {'weight': 6}}
# MmePontmercy {'MlleGillenormand': {'weight': 1}, 'Pontmercy': {'weight': 1}}
# MlleVaubois {'MlleGillenormand': {'weight': 1}}
# LtGillenormand {'MlleGillenormand': {'weight': 2}, 'Gillenormand': {'weight': 1}, 'Cosette': {'weight': 1}, 'Marius': {'weight': 1}}
# Marius {'MlleGillenormand': {'weight': 6}, 'Gillenormand': {'weight': 12}, 'Pontmercy': {'weight': 1}, 'LtGillenormand': {'weight': 1}, 'Cosette': {'weight': 21}, 'Valjean': {'weight': 19}, 'Tholomyes': {'weight': 1}, 'Thenardier': {'weight': 2}, 'Eponine': {'weight': 5}, 'Gavroche': {'weight': 4}, 'BaronessT': {'weight': 1}, 'Mabeuf': {'weight': 1}, 'Enjolras': {'weight': 7}, 'Combeferre': {'weight': 5}, 'Feuilly': {'weight': 1}, 'Courfeyrac': {'weight': 9}, 'Bahorel': {'weight': 1}, 'Bossuet': {'weight': 5}, 'Joly': {'weight': 2}}
# BaronessT {'Gillenormand': {'weight': 1}, 'Marius': {'weight': 1}}
# Mabeuf {'Marius': {'weight': 1}, 'Eponine': {'weight': 1}, 'Gavroche': {'weight': 1}, 'Enjolras': {'weight': 1}, 'Combeferre': {'weight': 2}, 'Feuilly': {'weight': 1}, 'Courfeyrac': {'weight': 2}, 'Bahorel': {'weight': 2}, 'Bossuet': {'weight': 1}, 'Joly': {'weight': 1}, 'MotherPlutarch': {'weight': 3}}
# Enjolras {'Marius': {'weight': 7}, 'Gavroche': {'weight': 7}, 'Javert': {'weight': 6}, 'Mabeuf': {'weight': 1}, 'Valjean': {'weight': 4}, 'Combeferre': {'weight': 15}, 'Prouvaire': {'weight': 4}, 'Feuilly': {'weight': 6}, 'Courfeyrac': {'weight': 17}, 'Bahorel': {'weight': 4}, 'Bossuet': {'weight': 10}, 'Joly': {'weight': 5}, 'Grantaire': {'weight': 3}, 'Claquesous': {'weight': 1}, 'MmeHucheloup': {'weight': 1}}
# Combeferre {'Enjolras': {'weight': 15}, 'Marius': {'weight': 5}, 'Gavroche': {'weight': 6}, 'Mabeuf': {'weight': 2}, 'Prouvaire': {'weight': 2}, 'Feuilly': {'weight': 5}, 'Courfeyrac': {'weight': 13}, 'Bahorel': {'weight': 5}, 'Bossuet': {'weight': 9}, 'Joly': {'weight': 5}, 'Grantaire': {'weight': 1}}
# Prouvaire {'Gavroche': {'weight': 1}, 'Enjolras': {'weight': 4}, 'Combeferre': {'weight': 2}, 'Feuilly': {'weight': 2}, 'Courfeyrac': {'weight': 3}, 'Bahorel': {'weight': 2}, 'Bossuet': {'weight': 2}, 'Joly': {'weight': 2}, 'Grantaire': {'weight': 1}}
# Feuilly {'Gavroche': {'weight': 2}, 'Enjolras': {'weight': 6}, 'Prouvaire': {'weight': 2}, 'Combeferre': {'weight': 5}, 'Mabeuf': {'weight': 1}, 'Marius': {'weight': 1}, 'Courfeyrac': {'weight': 6}, 'Bahorel': {'weight': 3}, 'Bossuet': {'weight': 6}, 'Joly': {'weight': 5}, 'Grantaire': {'weight': 1}}
# Courfeyrac {'Marius': {'weight': 9}, 'Enjolras': {'weight': 17}, 'Combeferre': {'weight': 13}, 'Gavroche': {'weight': 7}, 'Mabeuf': {'weight': 2}, 'Eponine': {'weight': 1}, 'Feuilly': {'weight': 6}, 'Prouvaire': {'weight': 3}, 'Bahorel': {'weight': 6}, 'Bossuet': {'weight': 12}, 'Joly': {'weight': 5}, 'Grantaire': {'weight': 2}, 'MmeHucheloup': {'weight': 1}}
# Bahorel {'Combeferre': {'weight': 5}, 'Gavroche': {'weight': 5}, 'Courfeyrac': {'weight': 6}, 'Mabeuf': {'weight': 2}, 'Enjolras': {'weight': 4}, 'Feuilly': {'weight': 3}, 'Prouvaire': {'weight': 2}, 'Marius': {'weight': 1}, 'Bossuet': {'weight': 4}, 'Joly': {'weight': 5}, 'Grantaire': {'weight': 1}, 'MmeHucheloup': {'weight': 1}}
# Bossuet {'Marius': {'weight': 5}, 'Courfeyrac': {'weight': 12}, 'Gavroche': {'weight': 5}, 'Bahorel': {'weight': 4}, 'Enjolras': {'weight': 10}, 'Feuilly': {'weight': 6}, 'Prouvaire': {'weight': 2}, 'Combeferre': {'weight': 9}, 'Mabeuf': {'weight': 1}, 'Valjean': {'weight': 1}, 'Joly': {'weight': 7}, 'Grantaire': {'weight': 3}, 'MmeHucheloup': {'weight': 1}}
# Joly {'Bahorel': {'weight': 5}, 'Bossuet': {'weight': 7}, 'Gavroche': {'weight': 3}, 'Courfeyrac': {'weight': 5}, 'Enjolras': {'weight': 5}, 'Feuilly': {'weight': 5}, 'Prouvaire': {'weight': 2}, 'Combeferre': {'weight': 5}, 'Mabeuf': {'weight': 1}, 'Marius': {'weight': 2}, 'Grantaire': {'weight': 2}, 'MmeHucheloup': {'weight': 1}}
# Grantaire {'Bossuet': {'weight': 3}, 'Enjolras': {'weight': 3}, 'Combeferre': {'weight': 1}, 'Courfeyrac': {'weight': 2}, 'Joly': {'weight': 2}, 'Gavroche': {'weight': 1}, 'Bahorel': {'weight': 1}, 'Feuilly': {'weight': 1}, 'Prouvaire': {'weight': 1}, 'MmeHucheloup': {'weight': 1}}
# MotherPlutarch {'Mabeuf': {'weight': 3}}
# Gueulemer {'Thenardier': {'weight': 5}, 'Valjean': {'weight': 1}, 'MmeThenardier': {'weight': 1}, 'Javert': {'weight': 1}, 'Gavroche': {'weight': 1}, 'Eponine': {'weight': 1}, 'Babet': {'weight': 6}, 'Claquesous': {'weight': 4}, 'Montparnasse': {'weight': 2}, 'Brujon': {'weight': 3}}
# Babet {'Thenardier': {'weight': 6}, 'Gueulemer': {'weight': 6}, 'Valjean': {'weight': 1}, 'MmeThenardier': {'weight': 1}, 'Javert': {'weight': 2}, 'Gavroche': {'weight': 1}, 'Eponine': {'weight': 1}, 'Claquesous': {'weight': 4}, 'Montparnasse': {'weight': 2}, 'Brujon': {'weight': 3}}
# Claquesous {'Thenardier': {'weight': 4}, 'Babet': {'weight': 4}, 'Gueulemer': {'weight': 4}, 'Valjean': {'weight': 1}, 'MmeThenardier': {'weight': 1}, 'Javert': {'weight': 1}, 'Eponine': {'weight': 1}, 'Enjolras': {'weight': 1}, 'Montparnasse': {'weight': 2}, 'Brujon': {'weight': 1}}
# Montparnasse {'Javert': {'weight': 1}, 'Babet': {'weight': 2}, 'Gueulemer': {'weight': 2}, 'Claquesous': {'weight': 2}, 'Valjean': {'weight': 1}, 'Gavroche': {'weight': 1}, 'Eponine': {'weight': 1}, 'Thenardier': {'weight': 1}, 'Brujon': {'weight': 1}}
# Toussaint {'Cosette': {'weight': 2}, 'Javert': {'weight': 1}, 'Valjean': {'weight': 1}}
# Child1 {'Gavroche': {'weight': 2}, 'Child2': {'weight': 3}}
# Child2 {'Gavroche': {'weight': 2}, 'Child1': {'weight': 3}}
# Brujon {'Babet': {'weight': 3}, 'Gueulemer': {'weight': 3}, 'Thenardier': {'weight': 3}, 'Gavroche': {'weight': 1}, 'Eponine': {'weight': 1}, 'Claquesous': {'weight': 1}, 'Montparnasse': {'weight': 1}}
# MmeHucheloup {'Bossuet': {'weight': 1}, 'Joly': {'weight': 1}, 'Grantaire': {'weight': 1}, 'Bahorel': {'weight': 1}, 'Courfeyrac': {'weight': 1}, 'Gavroche': {'weight': 1}, 'Enjolras': {'weight': 1}}

# %% [markdown]
# A primeira coisa que temos que pensar é que o peso da relações é grande quando a relação é forte, porém se pensarmos no algoritmo de Djikstra, ele busca o caminho de menor peso, por isso é essencial que inverta-se os pesos das relações, por exemplo:
#
# - Myriel -> MlleBaptistine: {'weight': 8}
#
# Precisamos que este peso se inverta, porém vamos ver quais são os intervalos destes valores para assim poder fazer a inversão.

# %%
maior_peso = 0
menor_peso = 1

for fonte, conexoes in G_dict.items():
    for nome, weight in conexoes.items():
        if weight['weight'] > maior_peso:
            maior_peso = weight['weight']
        
print(maior_peso)
# Out:
# 31

# %% [markdown]
# Identificamos o maior peso de todas as arestas para poder fazer a alteração já relatada anteriormente.
#
# Não foi necessário utilizar um método para identificar o menor peso, visto que quando o peso é '0', não há relação, e por também não termos nenhum peso negativo. Logo, o menor peso será 1.

# %% [markdown]
# Para o próximo passo, vamos fazer a inversão proporcional que se dará por uma subtração do peso máximo.

# %%
G_inv = {} 

for fonte, conexoes in G_dict.items():
    G_inv[fonte] = {}
    for nome, peso in conexoes.items():
        G_inv[fonte][nome] = {}
        G_inv[fonte][nome]['weight'] = maior_peso - peso['weight'] + 1

# %% [markdown]
# Precisamos verificar se realmente os pesos se inverteram, por isso vamos imprimir o grafo original e o grafo em que os pesos estão invertidos.

# %%
for fonte, conexoes in G_dict.items():
    print(f'Fonte: {fonte}')
    for nome, peso in conexoes.items():
        print('Nome: ' +nome+ ' | Peso antigo: '+str(peso['weight'])+' | Peso novo: '+str(G_inv[fonte][nome]['weight']))
    print('='*50)
# Out:
# Fonte: Napoleon
# Nome: Myriel | Peso antigo: 1 | Peso novo: 31
# ==================================================
# Fonte:
# Nome: Courfeyrac | Peso antigo: 1 | Peso novo: 31
# Nome: Gavroche | Peso antigo: 1 | Peso novo: 31
# Nome: Enjolras | Peso antigo: 1 | Peso novo: 31
# ==================================================

# %% [markdown]
# Certo! Após a verificação, conseguimos confirmar que tivemos sucesso ao fazer a inversão dos pesos.
#
# Agora vamos criar um dicionário com os nomes dos personagens para termos acesso a eles quando formos utilizar o algoritmo de Dijkstra a partir de uma matriz de adjacências, pois ela é indexada apenas por números.

# %%
dic_nome = {}

for indice, fonte in enumerate(G_dict.keys()):
    dic_nome[indice] = fonte

print(dic_nome)
# Out:
# {0: 'Napoleon', 1: 'Myriel', 2: 'MlleBaptistine', 3: 'MmeMagloire', 4: 'CountessDeLo', 5: 'Geborand', 6: 'Champtercier', 7: 'Cravatte', 8: 'Count', 9: 'OldMan', 10: 'Valjean', 11: 'Labarre', 12: 'Marguerite', 13: 'MmeDeR', 14: 'Isabeau', 15: 'Gervais', 16: 'Listolier', 17: 'Tholomyes', 18: 'Fameuil', 19: 'Blacheville', 20: 'Favourite', 21: 'Dahlia', 22: 'Zephine', 23: 'Fantine', 24: 'MmeThenardier', 25: 'Thenardier', 26: 'Cosette', 27: 'Javert', 28: 'Fauchelevent', 29: 'Bamatabois', 30: 'Perpetue', 31: 'Simplice', 32: 'Scaufflaire', 33: 'Woman1', 34: 'Judge', 35: 'Champmathieu', 36: 'Brevet', 37: 'Chenildieu', 38: 'Cochepaille', 39: 'Pontmercy', 40: 'Boulatruelle', 41: 'Eponine', 42: 'Anzelma', 43: 'Woman2', 44: 'MotherInnocent', 45: 'Gribier', 46: 'MmeBurgon', 47: 'Jondrette', 48: 'Gavroche', 49: 'Gillenormand', 50: 'Magnon', 51: 'MlleGillenormand', 52: 'MmePontmercy', 53: 'MlleVaubois', 54: 'LtGillenormand', 55: 'Marius', 56: 'BaronessT', 57: 'Mabeuf', 58: 'Enjolras', 59: 'Combeferre', 60: 'Prouvaire', 61: 'Feuilly', 62: 'Courfeyrac', 63: 'Bahorel', 64: 'Bossuet', 65: 'Joly', 66: 'Grantaire', 67: 'MotherPlutarch', 68: 'Gueulemer', 69: 'Babet', 70: 'Claquesous', 71: 'Montparnasse', 72: 'Toussaint', 73: 'Child1', 74: 'Child2', 75: 'Brujon', 76: 'MmeHucheloup'}

# %% [markdown]
# Agora, o próximo passo é utilizar o algoritmo de Dijkstra pra encontrar o menor caminho entre uma fonte e um destino.

# %%
def minDistance(dist,queue):

    minimum = float("Inf")
    min_index = -1

    for i in range(len(dist)):
        if dist[i] < minimum and i in queue:
            minimum = dist[i]
            min_index = i
    return min_index

# %%
def listaCaminho(parent, j):
    caminho = []
    while(j!=-1):
        caminho.append(dic_nome[j])
        j = parent[j]
        
    caminho.reverse()
    return caminho

# %%
def callback_caminho(dist, parent, src, dstny):

    h = 0
    for i in range(1, len(dist)):
        

        if i == dstny:
            h = 1
            return (listaCaminho(parent,i),dist[i])
    
    if h == 0:
        return -1,-1

# %%
def dijkstra(graph, src, dstny):

    row = len(graph)
    col = len(graph[0])

    dist = [float("Inf")] * row
    parent = [-1] * row
    dist[src] = 0
    queue = []

    for i in range(row):
        queue.append(i)

    while queue:

        u = minDistance(dist,queue)
        queue.remove(u)

        for i in range(col):
            if graph[u][i] and i in queue:
                if dist[u] + graph[u][i] < dist[i]:
                    dist[i] = dist[u] + graph[u][i]
                    parent[i] = u

    return callback_caminho(dist,parent, src, dstny)

# %% [markdown]
# Certo!
#
# Com o algoritmo implementado, faremos a transformação do dicionário para a matriz de adjacências.

# %%
g_m = nx.adjacency_matrix(nx.Graph(G_inv)).todense().tolist()

# %%
G = nx.Graph(G_inv)
pos = nx.spring_layout(G, seed=7)

plt.figure(figsize=(12,12))

# nodes
nx.draw_networkx_nodes(G, pos, node_size=400)

nx.draw_networkx_edges(G,pos)

weights = [d['weight']/10 for (u, v, d) in G.edges(data=True)]
colors = [d['weight']/10 for (u, v, d) in G.edges(data=True)]

nx.draw_networkx_edges(G, pos, width=weights, edge_color=colors, alpha=1)

# labels
nx.draw_networkx_labels(G, pos, font_size=10, font_family="sans-serif")

plt.show()

# %% [markdown]
# Feito isso, agora nós podemos aplicar o algoritmo de Dijkstra a fim de utilizar dois personagens (um de fonte e outro de destino) para encontrar o menor caminho — em relação aos pesos das arestas), simbolizando a relação dos personagens.
#
# A função a seguir tem 3 parâmetros:
#
# - g_m: este é o nosso grafo (representado por uma matriz de adjacências) que vai conter os pesos das arestas e nós que utilizaremos.
#
# - fonte: aqui utilizamos um número que corresponderá a algum personagem do 'Les Miserables'. Vai servir como fonte e ponto inicial da nossa busca. No exemplo abaixo, está representado pelo número '15'.
#
# - destino: aqui utilizamos um número que corresponderá a algum personagem do 'Les Miserables'. Vai servir como destino e ponto final da nossa busca.  No exemplo abaixo, está representado pelo número '55'.

# %%
caminho,peso = dijkstra(g_m, 0, 55)

print(f'Peso do caminho: {peso}')
print(f'Caminho:',' -> '.join(caminho))
# Out:
# Peso do caminho: 70
# Caminho: Napoleon -> Myriel -> Valjean -> Cosette -> Marius

# %% [markdown]
# ## Parte interativa
#
# Agora vamos organizar um menu de seleção para verificar uma pessoa contaminada e o caminho mais provável para que outra pessoa seja contaminada por esta pessoa contaminada

# %%
def invert_dic(d):
    return list({v: k for k, v in d.items()}.items())

# %%
contaminada = widgets.Dropdown(
    options=invert_dic(dic_nome),
    value=0,
    description='Contaminada:',
)

# %%
destino = widgets.Dropdown(
    options=invert_dic(dic_nome),
    value=6,
    description='Destino:',
)

# %%
display(contaminada)
display(destino)
# Out:
# Dropdown(description='Contaminada:', options=(('Napoleon', 0), ('Myriel', 1), ('MlleBaptistine', 2), ('MmeMagl…
# Dropdown(description='Destino:', index=6, options=(('Napoleon', 0), ('Myriel', 1), ('MlleBaptistine', 2), ('Mm…

# %%
caminho,peso = dijkstra(g_m, contaminada.value, destino.value)

if caminho!=-1 and peso!=-1:
    print(f'Peso do caminho: {peso}')
    print(f'Caminho:',' -> '.join(caminho))
else:
    print('Não há conexão')
# Out:
# Peso do caminho: 62
# Caminho: Napoleon -> Myriel -> Champtercier
